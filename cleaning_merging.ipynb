# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx

# %%
data = pd.read_excel("paneldata_wdi_labor_gdp.xlsx")
data.head(10)
# Out:
#      Country  Year  CollectiveBargain_Coverage  TradeUnions_Density
# 0  Australia  1960                         NaN            53.799999  \
# 1  Australia  1961                   92.000000            53.200001
# 2  Australia  1962                         NaN            51.400002
# 3  Australia  1963                         NaN            49.700001
# 4  Australia  1964                   90.699997            48.200001
# 5  Australia  1965                         NaN            47.900002
# 6  Australia  1966                         NaN            45.799999
# 7  Australia  1967                         NaN            45.000000
# 8  Australia  1968                         NaN            44.799999
# 9  Australia  1969                   88.300003            44.400002
#
#    Real Average Annual Wage Growth  Annual Inflation CPI  Gini Index
# 0                              NaN              3.728814         NaN  \
# 1                              NaN              2.287582         NaN
# 2                              NaN             -0.319489         NaN
# 3                              NaN              0.641026         NaN
# 4                              NaN              2.866242         NaN
# 5                              NaN              3.405573         NaN
# 6                              NaN              3.293413         NaN
# 7                              NaN              3.478261         NaN
# 8                              NaN              2.521008         NaN
# 9                              NaN              3.278688         NaN
#
#    Employment/population ratio Women age 15 to 64
# 0                                             NaN  \
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# 5                                             NaN
# 6                                       40.223370
# 7                                       41.105927
# 8                                       41.712722
# 9                                       42.185129
#
#    Labour force participation rate (Women age 15 to 64)
# 0                                                NaN     \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                          41.328994
# 7                                          42.313391
# 8                                          42.928047
# 9                                          43.351996
#
#    Unemployment rate (Women age 15 to 64)  ...
# 0                                     NaN  ...  \
# 1                                     NaN  ...
# 2                                     NaN  ...
# 3                                     NaN  ...
# 4                                     NaN  ...
# 5                                     NaN  ...
# 6                                2.675176  ...
# 7                                2.853622  ...
# 8                                2.831073  ...
# 9                                2.691611  ...
#
#    Coverage of social protection and labor programs (% of population)
# 0                                                NaN                   \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#    Current health expenditure (% of GDP)
# 0                                    NaN  \
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# 5                                    NaN
# 6                                    NaN
# 7                                    NaN
# 8                                    NaN
# 9                                    NaN
#
#    Exports of goods and services (annual % growth)
# 0                                              NaN  \
# 1                                         4.987326
# 2                                        13.546493
# 3                                        -2.226884
# 4                                        16.489846
# 5                                        -0.262374
# 6                                         1.451915
# 7                                        10.965393
# 8                                         4.801600
# 9                                         6.521879
#
#    Foreign direct investment, net inflows (% of GDP)
# 0                                                NaN  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#    Foreign direct investment, net outflows (% of GDP)
# 0                                                NaN   \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#    Imports of goods and services (% of GDP)  Labor force, total
# 0                                 14.037200                 NaN  \
# 1                                 14.999431                 NaN
# 2                                 12.609624                 NaN
# 3                                 13.810316                 NaN
# 4                                 13.740530                 NaN
# 5                                 15.241668                 NaN
# 6                                 15.105406                 NaN
# 7                                 13.869983                 NaN
# 8                                 14.461296                 NaN
# 9                                 13.311758                 NaN
#
#    Labor tax and contributions (% of commercial profits)
# 0                                                NaN      \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#    Part time employment, total (% of total employment)  GDP (current US$)
# 0                                                NaN         1.860656e+10
# 1                                                NaN         1.968288e+10
# 2                                                NaN         1.992256e+10
# 3                                                NaN         2.153984e+10
# 4                                                NaN         2.380112e+10
# 5                                                NaN         2.597616e+10
# 6                                                NaN         2.730784e+10
# 7                                                NaN         3.044272e+10
# 8                                                NaN         3.271409e+10
# 9                                                NaN         3.668337e+10
#
# [10 rows x 22 columns]

# %% [markdown]
# # Causal Map for the analysis

# %%
G = nx.DiGraph()

nodes_with_categories = {
    'Collective Bargain Coverage': 'Collective Bargaining',
    'Trade Unions Density': 'Collective Bargaining',
    'Gini Index': 'Income Inequality',
    'Real Average Annual Wage Growth': 'Economic',
    'Annual Inflation CPI': 'Economic',
    'Exports of goods and services (annual % growth)': 'Economic',
    'Foreign direct investment, net inflows (% of GDP)': 'Economic',
    'Foreign direct investment, net outflows (% of GDP)': 'Economic',
    'Imports of goods and services (% of GDP)': 'Economic',
    'Employment/population ratio Women age 15 to 64': 'Labor Market',
    'Labour force participation rate (Women age 15 to 64)': 'Labor Market',
    'Unemployment rate (Women age 15 to 64)': 'Labor Market',
    'Labor force, total': 'Labor Market',
    'Labor tax and contributions (% of commercial profits)': 'Labor Market',
    'Part time employment, total (% of total employment)': 'Labor Market'
}

for node in nodes_with_categories:
    G.add_node(node, category=nodes_with_categories[node])

edges = [
    ('Collective Bargain Coverage', 'Gini Index'),
    ('Trade Unions Density', 'Gini Index'),
    ('Trade Unions Density', 'Collective Bargain Coverage'),

    ('Real Average Annual Wage Growth', 'Gini Index'),

    ('Annual Inflation CPI', 'Gini Index'),
    ('Annual Inflation CPI', 'Real Average Annual Wage Growth'),
    ('Annual Inflation CPI', 'Labor tax and contributions (% of commercial profits)'),

    ('Employment/population ratio Women age 15 to 64', 'Gini Index'),

    ('Labour force participation rate (Women age 15 to 64)', 'Gini Index'),
    ('Unemployment rate (Women age 15 to 64)', 'Gini Index'),

    ('Labor tax and contributions (% of commercial profits)', 'Real Average Annual Wage Growth'),

    ('Part time employment, total (% of total employment)', 'Real Average Annual Wage Growth'),

    ('Labor force, total', 'Real Average Annual Wage Growth'),
    ('Labor force, total', 'Annual Inflation CPI'),
    ('Labor force, total', 'Collective Bargain Coverage'),
    ('Labor force, total', 'Employment/population ratio Women age 15 to 64'),

    ('Exports of goods and services (annual % growth)', 'Annual Inflation CPI'),

    ('Foreign direct investment, net inflows (% of GDP)', 'Annual Inflation CPI'),
    ('Foreign direct investment, net outflows (% of GDP)', 'Annual Inflation CPI'),

    ('Imports of goods and services (% of GDP)', 'Foreign direct investment, net outflows (% of GDP)')
]

G.add_edges_from(edges)

color_map = {
    'Collective Bargaining': 'lightblue',
    'Income Inequality': 'salmon',
    'Economic': 'lightgreen',
    'Labor Market': 'wheat'
}
node_colors = [color_map[G.nodes[node]['category']] for node in G.nodes]

# Draw the graph
plt.figure(figsize=(20, 15))
pos = nx.spring_layout(G, seed=6)
nx.draw_networkx(G, pos, with_labels=True, node_color=node_colors, edge_color='gray', node_size=3000, font_weight='bold', font_size=9)
plt.title('Causal Map: Collective Bargaining and Income Inequality', size=25)
plt.show()

# %% [markdown]
# # Data Cleaning

# %%
print(data['Country'].unique())
# Out:
# ['Australia' 'Austria' 'Belgium' 'Canada' 'Chile' 'Czechia' 'Denmark'
#  'Estonia' 'Finland' 'France' 'Germany' 'Greece' 'Hungary' 'Iceland'
#  'Ireland' 'Israel' 'Italy' 'Japan' 'Latvia' 'Lithuania' 'Luxembourg'
#  'Netherlands' 'New Zealand' 'Norway' 'Poland' 'Portugal'
#  'Slovak Republic' 'Slovenia' 'Spain' 'Sweden' 'Switzerland'
#  'United Kingdom' 'United States']

# %%
countries = ['Austria', 'Belgium', 'Czechia', 'Denmark', 'Estonia', 'Finland', 'France', 'Germany', 'Greece', 'Hungary', 'Iceland', 'Ireland', 'Italy', 'Latvia', 'Lithuania', 'Luxembourg', 'Netherlands', 'Norway', 'Poland', 'Portugal', 'Slovak Republic', 'Slovenia', 'Spain', 'Sweden', 'Switzerland', 'United Kingdom']
df = data[(data['Year'] >= 1990) & (data['Country'].isin(countries))]
df.head(10)
# Out:
#      Country  Year  CollectiveBargain_Coverage  TradeUnions_Density
# 93   Austria  1990                         NaN            46.799999  \
# 94   Austria  1991                        98.0            45.500000
# 95   Austria  1992                         NaN            44.500000
# 96   Austria  1993                         NaN            44.000000
# 97   Austria  1994                         NaN            41.500000
# 98   Austria  1995                         NaN            41.099998
# 99   Austria  1996                        98.0            40.099998
# 100  Austria  1997                         NaN            38.900002
# 101  Austria  1998                         NaN            38.400002
# 102  Austria  1999                         NaN            37.900002
#
#      Real Average Annual Wage Growth  Annual Inflation CPI  Gini Index
# 93                               NaN              3.261872         NaN  \
# 94                          3.125859              3.337426         NaN
# 95                          2.014635              4.020847         NaN
# 96                          0.815329              3.631786         NaN
# 97                          1.007529              2.953407        30.8
# 98                          0.805614              2.243364        29.9
# 99                         -0.661107              1.860974        29.3
# 100                        -0.862231              1.305983        29.1
# 101                         3.227776              0.922467        31.3
# 102                         2.234816              0.568986        29.7
#
#      Employment/population ratio Women age 15 to 64
# 93                                              NaN  \
# 94                                              NaN
# 95                                              NaN
# 96                                              NaN
# 97                                              NaN
# 98                                              NaN
# 99                                              NaN
# 100                                             NaN
# 101                                             NaN
# 102                                             NaN
#
#      Labour force participation rate (Women age 15 to 64)
# 93                                                 NaN     \
# 94                                                 NaN
# 95                                                 NaN
# 96                                                 NaN
# 97                                           61.315422
# 98                                           61.578041
# 99                                           61.042473
# 100                                          61.311236
# 101                                          61.390793
# 102                                          61.778667
#
#      Unemployment rate (Women age 15 to 64)  ...
# 93                                      NaN  ...  \
# 94                                      NaN  ...
# 95                                      NaN  ...
# 96                                      NaN  ...
# 97                                 4.012873  ...
# 98                                 4.392549  ...
# 99                                 4.512449  ...
# 100                                4.705196  ...
# 101                                4.649185  ...
# 102                                3.887604  ...
#
#      Coverage of social protection and labor programs (% of population)
# 93                                                 NaN                   \
# 94                                                 NaN
# 95                                                 NaN
# 96                                                 NaN
# 97                                                 NaN
# 98                                                 NaN
# 99                                                 NaN
# 100                                                NaN
# 101                                                NaN
# 102                                                NaN
#
#      Current health expenditure (% of GDP)
# 93                                     NaN  \
# 94                                     NaN
# 95                                     NaN
# 96                                     NaN
# 97                                     NaN
# 98                                     NaN
# 99                                     NaN
# 100                                    NaN
# 101                                    NaN
# 102                                    NaN
#
#      Exports of goods and services (annual % growth)
# 93                                          8.572220  \
# 94                                          2.937296
# 95                                          1.319386
# 96                                         -2.373161
# 97                                          5.688089
# 98                                          7.205394
# 99                                          4.638488
# 100                                        11.027821
# 101                                         7.851485
# 102                                         6.433960
#
#      Foreign direct investment, net inflows (% of GDP)
# 93                                            0.392278  \
# 94                                            0.207142
# 95                                            0.761499
# 96                                            0.590980
# 97                                            1.019884
# 98                                            0.757179
# 99                                            1.822338
# 100                                           1.254274
# 101                                           2.094684
# 102                                           1.369102
#
#      Foreign direct investment, net outflows (% of GDP)
# 93                                            1.021846   \
# 94                                            0.743983
# 95                                            0.902222
# 96                                            0.619051
# 97                                            0.609730
# 98                                            0.449536
# 99                                            0.796237
# 100                                           0.939127
# 101                                           1.268233
# 102                                           1.519343
#
#      Imports of goods and services (% of GDP)  Labor force, total
# 93                                  35.790955                 NaN  \
# 94                                  35.457917           3569407.0
# 95                                  34.474900           3652067.0
# 96                                  31.801153           3684501.0
# 97                                  33.828559           3851283.0
# 98                                  34.723461           3882088.0
# 99                                  35.834395           3852167.0
# 100                                 37.839607           3837968.0
# 101                                 38.576128           3877122.0
# 102                                 38.903102           3902046.0
#
#      Labor tax and contributions (% of commercial profits)
# 93                                                 NaN      \
# 94                                                 NaN
# 95                                                 NaN
# 96                                                 NaN
# 97                                                 NaN
# 98                                                 NaN
# 99                                                 NaN
# 100                                                NaN
# 101                                                NaN
# 102                                                NaN
#
#      Part time employment, total (% of total employment)  GDP (current US$)
# 93                                                 NaN         1.664634e+11
# 94                                                 NaN         1.737942e+11
# 95                                                 NaN         1.950781e+11
# 96                                                 NaN         1.903797e+11
# 97                                                 NaN         2.035352e+11
# 98                                               20.40         2.410383e+11
# 99                                               20.05         2.372509e+11
# 100                                              18.21         2.127903e+11
# 101                                              23.73         2.182599e+11
# 102                                              23.76         2.172591e+11
#
# [10 rows x 22 columns]

# %%
(df.isnull().sum() / len(df)) * 100
df.to_excel('2_paneldata_wdi_labor_gdp.xlsx', index=False)

# %% [markdown]
# # Treatment and Control Groups
#
# in order to have a treatment and control groups, I will take countries in EU with an effective minimum wage and controls will be countries without a minimum wage. and in order to ballance countries in both treatment and control group I will use average GDP from 1990 until 2022 to match in size.
#
# Countries with a minimum wage:
# - Germany
# - France
# - Spain
# - Belgium
# - Slovakia
# - Nethrlands
# - Luxemburg
# - Portugal
#
# Countries without a minimum wage:
# - Austria
# - Italy
# - Denmark
# - Finland
# - Sweden
# - Norway

# %% [markdown]
# ### Merging the minimum wage with the panel data

# %%
minimum_wage_cleaned_path = '/Users/jacopobinati/Desktop/thesis/2_paneldata_wdi_labor_gdp.xlsx'
paneldata_wdi_labor_gdp_path = '/Users/jacopobinati/Desktop/thesis/minimum wage/minimum_wage_cleaned_PD.xlsx'

minimum_wage_cleaned = pd.read_excel(minimum_wage_cleaned_path)
paneldata_wdi_labor_gdp = pd.read_excel(paneldata_wdi_labor_gdp_path)

# Merge on 'Country' and 'Year'
merged_data = pd.merge(paneldata_wdi_labor_gdp, minimum_wage_cleaned, on=['Country', 'Year'], how='outer')

# Fill missing values with 0
merged_data['Real Minimum Wage'] = merged_data['Real Minimum Wage'].fillna(0)

# %%
merged_data['Monthly Minimum Wage'] = merged_data['Monthly Minimum Wage'].fillna(0)
merged_data['Country'].unique()
# Out:
# array(['Belgium', 'France', 'Germany', 'Hungary', 'Ireland', 'Luxembourg',
#        'Netherlands', 'Poland', 'Portugal', 'Slovak Republic', 'Spain',
#        'Croatia', 'Romania', 'Austria', 'Czechia', 'Denmark', 'Estonia',
#        'Finland', 'Greece', 'Iceland', 'Italy', 'Latvia', 'Lithuania',
#        'Norway', 'Slovenia', 'Sweden', 'Switzerland', 'United Kingdom'],
#       dtype=object)

# %%
merged_data.to_excel('merged_data.xlsx', index=False)

# %% [markdown]
# # Creating treatment and control based on minimum wage

# %%
treatment_countries = [
    'Belgium', 'France', 'Germany', 'Hungary', 'Ireland', 'Luxembourg',
    'Netherlands', 'Poland', 'Portugal', 'Slovak Republic', 'Spain', 'Croatia',
    'Romania'
]

merged_data['Treatment'] = merged_data['Country'].apply(lambda x: 1 if x in treatment_countries else 0)

# %%
treatment_groups = merged_data.groupby('Treatment')['Country'].unique()
print("Countries with Treatment = 1: ", treatment_groups[1])
print("Countries with Treatment = 0: ", treatment_groups[0])
# Out:
# Countries with Treatment = 1:  ['Belgium' 'France' 'Germany' 'Hungary' 'Ireland' 'Luxembourg'
#  'Netherlands' 'Poland' 'Portugal' 'Slovak Republic' 'Spain' 'Croatia'
#  'Romania']
# Countries with Treatment = 0:  ['Austria' 'Czechia' 'Denmark' 'Estonia' 'Finland' 'Greece' 'Iceland'
#  'Italy' 'Latvia' 'Lithuania' 'Norway' 'Slovenia' 'Sweden' 'Switzerland'
#  'United Kingdom']

# %%
df1
# Out:
#             Country  Year  Real Minimum Wage  Monthly Minimum Wage
# 0           Belgium  1990       26202.014218           2183.501185  \
# 1            France  1990       20145.492469           1678.791039
# 2           Germany  1990           0.000000              0.000000
# 3           Hungary  1990        5291.874409            440.989534
# 4           Ireland  1990           0.000000              0.000000
# ..              ...   ...                ...                   ...
# 919  United Kingdom  2018           0.000000              0.000000
# 920  United Kingdom  2019           0.000000              0.000000
# 921  United Kingdom  2020           0.000000              0.000000
# 922  United Kingdom  2021           0.000000              0.000000
# 923  United Kingdom  2022           0.000000              0.000000
#
#      CollectiveBargain_Coverage  TradeUnions_Density
# 0                           NaN            50.599998  \
# 1                           NaN            10.700000
# 2                           NaN            31.200001
# 3                           NaN            88.599998
# 4                           NaN            51.099998
# ..                          ...                  ...
# 919                        26.0            23.400000
# 920                        26.0            23.500000
# 921                        26.9                  NaN
# 922                         NaN                  NaN
# 923                         NaN                  NaN
#
#      Real Average Annual Wage Growth  Annual Inflation CPI  Gini Index
# 0                                NaN              3.448310         NaN  \
# 1                                NaN              3.194282        32.1
# 2                                NaN              2.696470         NaN
# 3                                NaN             28.369590         NaN
# 4                                NaN              3.317329         NaN
# ..                               ...                   ...         ...
# 919                         0.900000              2.300000        33.7
# 920                         1.400000              1.700000        32.8
# 921                        -2.000000              1.000000        32.6
# 922                         2.144810              2.500000         NaN
# 923                        -1.419303              7.900000         NaN
#
#      Employment/population ratio Women age 15 to 64  ...
# 0                                               NaN  ...  \
# 1                                               NaN  ...
# 2                                               NaN  ...
# 3                                               NaN  ...
# 4                                               NaN  ...
# ..                                              ...  ...
# 919                                             NaN  ...
# 920                                             NaN  ...
# 921                                             NaN  ...
# 922                                             NaN  ...
# 923                                             NaN  ...
#
#      Current health expenditure (% of GDP)
# 0                                      NaN  \
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 919                               9.658155
# 920                               9.874801
# 921                              11.977593
# 922                              11.939087
# 923                                    NaN
#
#      Exports of goods and services (annual % growth)
# 0                                           4.573915  \
# 1                                           4.145828
# 2                                          11.348747
# 3                                                NaN
# 4                                           8.729924
# ..                                               ...
# 919                                         3.086065
# 920                                         1.996940
# 921                                       -11.469713
# 922                                         4.941180
# 923                                         8.970321
#
#      Foreign direct investment, net inflows (% of GDP)
# 0                                             3.918892  \
# 1                                             1.038725
# 2                                             0.144310
# 3                                                  NaN
# 4                                             1.261339
# ..                                                 ...
# 919                                          -0.872604
# 920                                           0.694070
# 921                                           4.910509
# 922                                           0.188516
# 923                                           1.428484
#
#      Foreign direct investment, net outflows (% of GDP)
# 0                                             3.075238   \
# 1                                             2.743777
# 2                                             1.356736
# 3                                                  NaN
# 4                                             0.738017
# ..                                                 ...
# 919                                          -0.997170
# 920                                          -0.753954
# 921                                          -0.164757
# 922                                           5.122765
# 923                                           5.144775
#
#      Imports of goods and services (% of GDP)  Labor force, total
# 0                                   59.854160                 NaN  \
# 1                                   21.760322                 NaN
# 2                                   23.027751                 NaN
# 3                                         NaN                 NaN
# 4                                   50.323209                 NaN
# ..                                        ...                 ...
# 919                                 32.962537          34415434.0
# 920                                 33.030353          34695933.0
# 921                                 29.082569          34633314.0
# 922                                 29.751335          34311328.0
# 923                                 36.094479          34376365.0
#
#      Labor tax and contributions (% of commercial profits)
# 0                                                  NaN      \
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 919                                               10.8
# 920                                               12.0
# 921                                                NaN
# 922                                                NaN
# 923                                                NaN
#
#      Part time employment, total (% of total employment)  GDP (current US$)
# 0                                                18.24         2.053317e+11  \
# 1                                                23.43         1.269180e+12
# 2                                                20.52         1.771671e+12
# 3                                                  NaN                  NaN
# 4                                                17.83         4.930563e+10
# ..                                                 ...                  ...
# 919                                              41.71         2.871340e+12
# 920                                              41.11         2.851407e+12
# 921                                                NaN         2.697807e+12
# 922                                                NaN         3.141506e+12
# 923                                                NaN         3.089073e+12
#
#      Treatment
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
# ..         ...
# 919          0
# 920          0
# 921          0
# 922          0
# 923          0
#
# [858 rows x 25 columns]

# %%
df1 = merged_data
df1['Country'].unique()
# Out:
# array(['Belgium', 'France', 'Germany', 'Hungary', 'Ireland', 'Luxembourg',
#        'Netherlands', 'Poland', 'Portugal', 'Slovak Republic', 'Spain',
#        'Croatia', 'Romania', 'Austria', 'Czechia', 'Denmark', 'Estonia',
#        'Finland', 'Greece', 'Iceland', 'Italy', 'Latvia', 'Lithuania',
#        'Norway', 'Slovenia', 'Sweden', 'Switzerland', 'United Kingdom'],
#       dtype=object)

# %% [markdown]
# ## Now let's check for average GDP and creating balanced control and treatment groups based on average GDP

# %%
average_gdp = df1.groupby('Country')['GDP (current US$)'].mean()
log_average_gdp = np.log(average_gdp)
log_average_gdp
# Out:
# Country
# Austria            26.503843
# Belgium            26.694102
# Croatia                  NaN
# Czechia            25.716937
# Denmark            26.292178
# Estonia            23.653546
# Finland            26.032909
# France             28.391624
# Germany            28.723749
# Greece             26.017486
# Hungary            25.368022
# Iceland            23.397686
# Ireland            26.077212
# Italy              28.168252
# Latvia             23.832669
# Lithuania          24.261492
# Luxembourg         24.497150
# Netherlands        27.230828
# Norway             26.467542
# Poland             26.578872
# Portugal           25.921036
# Romania                  NaN
# Slovak Republic    24.897322
# Slovenia           24.423446
# Spain              27.674898
# Sweden             26.745142
# Switzerland        26.933160
# United Kingdom     28.427702
# Name: GDP (current US$), dtype: float64

# %%
df1 = df1[~((df1['Country'] == 'Romania') | (df1['Country'] == 'Croatia'))]
df1['Country'].unique()
# Out:
# array(['Belgium', 'France', 'Germany', 'Hungary', 'Ireland', 'Luxembourg',
#        'Netherlands', 'Poland', 'Portugal', 'Slovak Republic', 'Spain',
#        'Austria', 'Czechia', 'Denmark', 'Estonia', 'Finland', 'Greece',
#        'Iceland', 'Italy', 'Latvia', 'Lithuania', 'Norway', 'Slovenia',
#        'Sweden', 'Switzerland', 'United Kingdom'], dtype=object)

# %%
df1
# Out:
#             Country  Year  Real Minimum Wage  Monthly Minimum Wage
# 0           Belgium  1990       26202.014218           2183.501185  \
# 1            France  1990       20145.492469           1678.791039
# 2           Germany  1990           0.000000              0.000000
# 3           Hungary  1990        5291.874409            440.989534
# 4           Ireland  1990           0.000000              0.000000
# ..              ...   ...                ...                   ...
# 919  United Kingdom  2018           0.000000              0.000000
# 920  United Kingdom  2019           0.000000              0.000000
# 921  United Kingdom  2020           0.000000              0.000000
# 922  United Kingdom  2021           0.000000              0.000000
# 923  United Kingdom  2022           0.000000              0.000000
#
#      CollectiveBargain_Coverage  TradeUnions_Density
# 0                           NaN            50.599998  \
# 1                           NaN            10.700000
# 2                           NaN            31.200001
# 3                           NaN            88.599998
# 4                           NaN            51.099998
# ..                          ...                  ...
# 919                        26.0            23.400000
# 920                        26.0            23.500000
# 921                        26.9                  NaN
# 922                         NaN                  NaN
# 923                         NaN                  NaN
#
#      Real Average Annual Wage Growth  Annual Inflation CPI  Gini Index
# 0                                NaN              3.448310         NaN  \
# 1                                NaN              3.194282        32.1
# 2                                NaN              2.696470         NaN
# 3                                NaN             28.369590         NaN
# 4                                NaN              3.317329         NaN
# ..                               ...                   ...         ...
# 919                         0.900000              2.300000        33.7
# 920                         1.400000              1.700000        32.8
# 921                        -2.000000              1.000000        32.6
# 922                         2.144810              2.500000         NaN
# 923                        -1.419303              7.900000         NaN
#
#      Employment/population ratio Women age 15 to 64  ...
# 0                                               NaN  ...  \
# 1                                               NaN  ...
# 2                                               NaN  ...
# 3                                               NaN  ...
# 4                                               NaN  ...
# ..                                              ...  ...
# 919                                             NaN  ...
# 920                                             NaN  ...
# 921                                             NaN  ...
# 922                                             NaN  ...
# 923                                             NaN  ...
#
#      Current health expenditure (% of GDP)
# 0                                      NaN  \
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 919                               9.658155
# 920                               9.874801
# 921                              11.977593
# 922                              11.939087
# 923                                    NaN
#
#      Exports of goods and services (annual % growth)
# 0                                           4.573915  \
# 1                                           4.145828
# 2                                          11.348747
# 3                                                NaN
# 4                                           8.729924
# ..                                               ...
# 919                                         3.086065
# 920                                         1.996940
# 921                                       -11.469713
# 922                                         4.941180
# 923                                         8.970321
#
#      Foreign direct investment, net inflows (% of GDP)
# 0                                             3.918892  \
# 1                                             1.038725
# 2                                             0.144310
# 3                                                  NaN
# 4                                             1.261339
# ..                                                 ...
# 919                                          -0.872604
# 920                                           0.694070
# 921                                           4.910509
# 922                                           0.188516
# 923                                           1.428484
#
#      Foreign direct investment, net outflows (% of GDP)
# 0                                             3.075238   \
# 1                                             2.743777
# 2                                             1.356736
# 3                                                  NaN
# 4                                             0.738017
# ..                                                 ...
# 919                                          -0.997170
# 920                                          -0.753954
# 921                                          -0.164757
# 922                                           5.122765
# 923                                           5.144775
#
#      Imports of goods and services (% of GDP)  Labor force, total
# 0                                   59.854160                 NaN  \
# 1                                   21.760322                 NaN
# 2                                   23.027751                 NaN
# 3                                         NaN                 NaN
# 4                                   50.323209                 NaN
# ..                                        ...                 ...
# 919                                 32.962537          34415434.0
# 920                                 33.030353          34695933.0
# 921                                 29.082569          34633314.0
# 922                                 29.751335          34311328.0
# 923                                 36.094479          34376365.0
#
#      Labor tax and contributions (% of commercial profits)
# 0                                                  NaN      \
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 919                                               10.8
# 920                                               12.0
# 921                                                NaN
# 922                                                NaN
# 923                                                NaN
#
#      Part time employment, total (% of total employment)  GDP (current US$)
# 0                                                18.24         2.053317e+11  \
# 1                                                23.43         1.269180e+12
# 2                                                20.52         1.771671e+12
# 3                                                  NaN                  NaN
# 4                                                17.83         4.930563e+10
# ..                                                 ...                  ...
# 919                                              41.71         2.871340e+12
# 920                                              41.11         2.851407e+12
# 921                                                NaN         2.697807e+12
# 922                                                NaN         3.141506e+12
# 923                                                NaN         3.089073e+12
#
#      Treatment
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
# ..         ...
# 919          0
# 920          0
# 921          0
# 922          0
# 923          0
#
# [858 rows x 25 columns]

# %%
unique_countries = df['Country'].unique()
colors = ['blue' if country in treatment_countries else 'orange' for country in unique_countries]

# Plot the data
log_average_gdp_sorted = log_average_gdp.sort_values()
log_average_gdp_sorted.plot(kind='bar', color=colors)

plt.xlabel('Country')
plt.ylabel('Log Average GDP')
plt.title('Log Average GDP per Country')
plt.show()

# %%
to_keep = ['Germany', 'France', 'Spain', 'Belgium', 'Slovakia', 'Netherlands', 'Luxembourg', 'Portugal', 'Austria', 'Italy', 'Denmark', 'Finland', 'Sweden', 'Norway']
data2 = df1[df1['Country'].isin(to_keep)]

# %%
data2.to_excel('Data Finale.xlsx', index=False)

# %% [markdown]
# # To do: define countries for treatment and control
