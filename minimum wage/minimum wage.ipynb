# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('minimum_wage_PD.xlsx')
data
# Out:
#              Country  Year  Real Minimum Wage
# 0            Belgium  1960                NaN
# 1             France  1960        7280.100631
# 2            Germany  1960                NaN
# 3            Hungary  1960                NaN
# 4            Ireland  1960                NaN
# ..               ...   ...                ...
# 814         Portugal  2022       15394.333575
# 815  Slovak Republic  2022       11837.572381
# 816            Spain  2022       20329.099072
# 817          Croatia  2022       14494.139017
# 818          Romania  2022       15053.987732
#
# [819 rows x 3 columns]

# %%
data = data[data['Year'] >= 1990]
data.head(5)
# Out:
#      Country  Year  Real Minimum Wage
# 390  Belgium  1990       26202.014218
# 391   France  1990       20145.492469
# 392  Germany  1990                NaN
# 393  Hungary  1990        5291.874409
# 394  Ireland  1990                NaN

# %%
data['Monthly Minimum Wage'] = data['Real Minimum Wage'] / 12
# Out:
# /var/folders/6t/d3d0rh5d1rd426bk9g_mnhd00000gn/T/ipykernel_98789/2451136809.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Monthly Minimum Wage'] = data['Real Minimum Wage'] / 12

# %%
plt.figure(figsize=(20,10))
grouped = data.groupby('Country')
for name, group in grouped:
    plt.plot(group['Year'], group['Monthly Minimum Wage'], label=name)

plt.legend(loc='lower right')
plt.xlabel('Year')
plt.ylabel('Monthly Real Minimum Wage')
plt.grid()
plt.show()

# %%
print(data['Country'].unique())
# Out:
# ['Belgium' 'France' 'Germany' 'Hungary' 'Ireland' 'Luxembourg'
#  'Netherlands' 'Poland' 'Portugal' 'Slovak Republic' 'Spain' 'Croatia'
#  'Romania']

# %%
data.to_excel('minimum_wage_cleaned_PD.xlsx', index=False)
